# %% [markdown]
# # Explore routes (optional, viewer-only)
#
# Not part of the pipeline. Purely for ad-hoc exploration -- imports
# `src/routing/` and calls the same functions the dashboard and
# `main.py`'s routing stage use. No training or preprocessing code
# belongs in this notebook.
